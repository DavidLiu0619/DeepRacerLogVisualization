# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidLiu0619/DeepRacerLogVisualization/blob/main/Log_Visualization_Li_Yuan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
log_begin = pd.read_csv("https://deepracer.hyl.gd.edu.kg/0-iteration.csv")
log_end = pd.read_csv("https://deepracer.hyl.gd.edu.kg/8425-iteration.csv")

# %%
plt.scatter(np.array(log_end["X"]), np.array(log_end["Y"]))
plt.show()
